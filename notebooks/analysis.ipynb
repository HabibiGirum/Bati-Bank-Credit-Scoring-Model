# %% [markdown]
# # import necessary python libraries to perform my tasks

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.task_2_eda import EDA
eda= EDA('../data/data.csv')
eda.sample_of_dataset()
# Out:
#                             BatchId       AccountId       SubscriptionId  \
# TransactionId
# TransactionId_99193  BatchId_121984  AccountId_3210  SubscriptionId_3348
#
#                           CustomerId CurrencyCode  CountryCode    ProviderId  \
# TransactionId
# TransactionId_99193  CustomerId_3638          UGX          256  ProviderId_1
#
#                         ProductId     ProductCategory    ChannelId  Amount  \
# TransactionId
# TransactionId_99193  ProductId_15  financial_services  ChannelId_3  5000.0
#
#                      Value      TransactionStartTime  PricingStrategy  \
# TransactionId
# TransactionId_99193   5000 2019-01-27 14:31:17+00:00                2
#
#                      FraudResult
# TransactionId
# TransactionId_99193            0

# %%
eda.get_overview_of_the_dataset()
# Out:
# {'row and columns of dataset': (95662, 15),
#  'data type of the dataset': BatchId                              object
#  AccountId                            object
#  SubscriptionId                       object
#  CustomerId                           object
#  CurrencyCode                         object
#  CountryCode                           int64
#  ProviderId                           object
#  ProductId                            object
#  ProductCategory                      object
#  ChannelId                            object
#  Amount                              float64
#  Value                                 int64
#  TransactionStartTime    datetime64[ns, UTC]
#  PricingStrategy                       int64
#  FraudResult                           int64
#  dtype: object}

# %%
eda.get_summery_statics()
# Out:
# {'describe':        CountryCode        Amount         Value  PricingStrategy   FraudResult
#  count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
#  mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
#  std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
#  min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
#  25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
#  50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
#  75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
#  max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000,
#  'Skewness': CountryCode         0.000000
#  Amount             51.098490
#  Value              51.291086
#  PricingStrategy     1.659057
#  FraudResult        22.196295
#  dtype: float64,
#  'kurtosis': CountryCode           0.000000
#  Amount             3363.127739
#  Value              3378.069274
#  PricingStrategy       2.087534
#  FraudResult         490.685762
#  dtype: float64}

# %%
eda.plot_distribution_of_each_column()
# Out:
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:31: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(self.df[column], fill = True, label =column)

# %%
eda.distribution_of_categorical_features()
# Out:
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=column, palette='pastel')
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=column, palette='pastel')
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=column, palette='pastel')
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=column, palette='pastel')
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=column, palette='pastel')
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=column, palette='pastel')
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=column, palette='pastel')
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=column, palette='pastel')
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=column, palette='pastel')
# /Users/senaiahderom/Documents/10Academy-kifya/week-6/scripts/task_2_eda.py:45: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
eda.correlation_analysis()

# %%
eda.identifying_missing_values()
# Out:
#                       Missing Values  Percentage
# BatchId                            0         0.0
# AccountId                          0         0.0
# SubscriptionId                     0         0.0
# CustomerId                         0         0.0
# CurrencyCode                       0         0.0
# CountryCode                        0         0.0
# ProviderId                         0         0.0
# ProductId                          0         0.0
# ProductCategory                    0         0.0
# ChannelId                          0         0.0
# Amount                             0         0.0
# Value                              0         0.0
# TransactionStartTime               0         0.0
# PricingStrategy                    0         0.0
# FraudResult                        0         0.0
